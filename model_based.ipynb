# %%
import pandas as pd
import numpy as np
data=np.array([[10,5,12,0,7],[0,12,23,8,8],[11,9,4,10,6],[0,0,8,0,12],[1,10,7,12,3]])
max_dirt=data.sum()
environment=pd.DataFrame(data)
environment
# Out:
#     0   1   2   3   4
# 0  10   5  12   0   7
# 1   0  12  23   8   8
# 2  11   9   4  10   6
# 3   0   0   8   0  12
# 4   1  10   7  12   3

# %%
def tracker(x,y,environment,dirt_collected):
    time_count=0
    travel_time=10
    if x==0 and y==0:
            if environment.iloc[x,y]==0:
                time_count+=10
            elif environment.iloc[x,y]==7:
                time_count=2 *(environment.iloc[x,y]//7 )
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0

            else:
                time_count+= 2 *(environment.iloc[x,y]//7 + 1)
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
                down=environment.iloc[x+1,y]
                right=environment.iloc[x,y+1]
                if down >right:
                    x=x+1
                    time_count+=travel_time
                else:
                    y=y+1
                    time_count+=travel_time
                

    elif x==0 and y==4:
            if environment.iloc[x,y]==0:
                time_count+=10
            elif environment.iloc[x,y]==7:
                time_count=2 *(environment.iloc[x,y]//7 )
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
            else:
                time_count+=2 *(environment.iloc[x,y]//7 + 1)
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
                down=environment.iloc[x+1,y]
                left=environment.iloc[x,y-1]
                if down >left:
                    x=x+1
                    time_count+=travel_time
                else:
                    y=y-1
                    time_count+=travel_time
        
        
    elif y==0 and x==4:
            if environment.iloc[x,y]==0:
                time_count+=10
            elif environment.iloc[x,y]==7:
                time_count=2 *(environment.iloc[x,y]//7 )
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
            else:
                time_count+=2 *(environment.iloc[x,y]//7 + 1)
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
                up=environment.iloc[x-1,y]
                right=environment.iloc[x,y+1]
                if up > right:
                    x=x-1
                    time_count+=travel_time
                else:
                    y=y+1
                    time_count+=travel_time

    elif x==4 and y==4:
            if environment.iloc[x,y]==0:
                time_count+=10
            elif environment.iloc[x,y]==7:
                time_count=2 *(environment.iloc[x,y]//7 ) 
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
            else:
                time_count+=2 *(environment.iloc[x,y]//7 + 1)
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
                up=environment.iloc[x-1,y]
                left=environment.iloc[x,y-1]
                if up > left:
                    x=x-1
                    time_count+=travel_time
                else:
                    y=y+1
                    time_count+=travel_time
    elif x==0:
            if environment.iloc[x,y]==0:
                time_count+=10
            elif environment.iloc[x,y]==7:
                time_count=2* (environment.iloc[x,y]//7 ) 
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
            else:
                time_count+=2 *(environment.iloc[x,y]//7 + 1)
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
                right=environment.iloc[x,y+1]
                down=environment.iloc[x+1,y]
                left=environment.iloc[x,y-1]
                block=min(down,left,right)
                if block==left:
                    y=y-1
                    time_count+=travel_time
                elif block==right:
                    y=y+1
                    time_count+=travel_time
                else:
                    x=x+1
                    time_count+=travel_time

    
    elif y==0:
            if environment.iloc[x,y]==0:
                time_count+=10
            elif environment.iloc[x,y]==7:
                time_count=2 * (environment.iloc[x,y]//7 ) 
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
            else:
                time_count+=2 *(environment.iloc[x,y]//7 + 1)
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
                up=environment.iloc[x-1,y]
                right=environment.iloc[x,y+1]
                down=environment.iloc[x+1,y]
                block=min(up,right,down)
                if block==down:
                    x=x+1
                    time_count+=travel_time
                elif block==right:
                    y=y+1
                    time_count+=travel_time
                else:
                    y=y-1
                    time_count+=travel_time
    
    elif x==4:
            if environment.iloc[x,y]==0:
                time_count+=10
            elif environment.iloc[x,y]==7:
                time_count=2 *(environment.iloc[x,y]//7 ) 
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
            else:
                time_count+= 2 *(environment.iloc[x,y]//7 + 1)
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
                up=environment.iloc[x-1,y]
                right=environment.iloc[x,y+1]
                left=environment.iloc[x,y-1]
                block=min(up,right,left)
                if block==left:
                    y=y-1
                    time_count+=travel_time
                elif block==right:
                    y=y+1
                    time_count+=travel_time
                else:
                    x=x-1
                    time_count+=travel_time

    elif y==4:
            if environment.iloc[x,y]==0:
                time_count+=10
            elif environment.iloc[x,y]==7:
                time_count=2 *(environment.iloc[x,y]//7 )
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
            else:
                time_count+=2*(environment.iloc[x,y]//7 + 1 )
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
                up=environment.iloc[x-1,y]
                left=environment.iloc[x,y-1]
                down=environment.iloc[x+1,y]
                block=max(up,left,down)
                if block==left:
                    y=y-1
                    time_count+=travel_time
                elif block==up:
                    x=x-1
                    time_count+=travel_time
                else:
                    x=x+1
                    time_count+=travel_time
    else:
            if environment.iloc[x,y]==0:
                time_count+=10
            elif environment.iloc[x,y]==7:
                time_count= 2* (environment.iloc[x,y]//7 )
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
            else:
                time_count+= 2 *(environment.iloc[x,y]//7 + 1)
                dirt_collected+=environment.iloc[x,y]
                environment.iloc[x,y]=0
                up=environment.iloc[x-1,y]
                down=environment.iloc[x+1,y]
                left=environment.iloc[x,y-1]
                right=environment.iloc[x,y+1]
                block=min(left,right,up,down)
                if block==left:
                    y=y-1
                    time_count+=travel_time
                elif block==right:
                    y=y+1
                    time_count+=travel_time
                elif block== up:
                    x=x-1
                    time_count+=travel_time
                else:
                    x=x+1
                    time_count+=travel_time
    return time_count,dirt_collected,x,y


def halt(x,y,environment):
    x=np.random.randint(0,4)
    y=np.random.randint(0,4)
    up=environment.iloc[x-1,y]
    down=environment.iloc[x+1,y]
    left=environment.iloc[x,y-1]
    right=environment.iloc[x,y+1]
    if up==0 and down==0 and left==0 and right==0:
        return True
    else:
        return False
time_count=0
cycles=0
dirt_collected=0
for x in range(5):
    for y in range(5):
        if x==0 and y==0:
            #x=np.random.randint(0,5)
            #y=np.random.randint(0,5)
            count,dirt_collected,i,j=tracker(x,y,environment,dirt_collected)
            count,dirt_collected,i,j=tracker(i,j,environment,dirt_collected)
            cycles+=1
            time_count+=count

        else:
            count,dirt_collected,i,j=tracker(i,j,environment,dirt_collected)
            count,dirt_collected,i,j=tracker(x,y,environment,dirt_collected)
            cycles+=1
            time_count+=count
        print("Percentage DIRT Collected: {:.2f} %".format((dirt_collected*100)/max_dirt))

print(" \n DIRT COLLECTED : {} in {} seconds".format(dirt_collected,time_count +2)) 
print(" Dirt collected {:.2f}% Remaining dirt: {:.2f}%".format((dirt_collected*100)/max_dirt,100-(dirt_collected*100)/max_dirt))
# Out:
# Percentage DIRT Collected: 8.43 %
# Percentage DIRT Collected: 8.43 %
# Percentage DIRT Collected: 15.17 %
# Percentage DIRT Collected: 15.17 %
# Percentage DIRT Collected: 19.10 %
# Percentage DIRT Collected: 19.10 %
# Percentage DIRT Collected: 25.84 %
# Percentage DIRT Collected: 38.76 %
# Percentage DIRT Collected: 43.26 %
# Percentage DIRT Collected: 47.75 %
# Percentage DIRT Collected: 57.30 %
# Percentage DIRT Collected: 62.36 %
# Percentage DIRT Collected: 64.61 %
# Percentage DIRT Collected: 70.22 %
# Percentage DIRT Collected: 70.22 %
# Percentage DIRT Collected: 70.22 %
# Percentage DIRT Collected: 70.22 %
# Percentage DIRT Collected: 74.72 %
# Percentage DIRT Collected: 74.72 %
# Percentage DIRT Collected: 81.46 %
# Percentage DIRT Collected: 83.71 %
# Percentage DIRT Collected: 89.33 %
# Percentage DIRT Collected: 93.26 %
# Percentage DIRT Collected: 100.00 %
# Percentage DIRT Collected: 100.00 %
#
#  DIRT COLLECTED : 178 in 290 seconds
#  Dirt collected 100.00% Remaining dirt: 0.00%
